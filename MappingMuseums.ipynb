# %% [markdown]
# <a href="https://colab.research.google.com/github/packetech/Visualization/blob/main/MappingMuseums.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

# display all columns
pd.set_option('display.max_columns', None)

# %%
Map = pd.read_csv('/content/sample_data/MappingMuseumsData2021_09_30_processed_v2.csv')

# %%
Map.dtypes
# Out:
# museum_id                             object
# museum_name                           object
# address_line_1                        object
# address_line_2                        object
# city                                  object
# postcode                              object
# latitude                             float64
# longitude                            float64
# admin_area_full                       object
# admin_area_1                          object
# admin_area_2                          object
# admin_area_2_type                     object
# admin_area_3                          object
# admin_area_3_type                     object
# admin_area_4                          object
# admin_area_4_type                     object
# accreditation                         object
# governance_type                       object
# governance_subtype                    object
# size                                  object
# size_provenance                       object
# subject_matter_full                   object
# subject_matter                        object
# subject_matter_subtype_1              object
# subject_matter_subtype_2              object
# year_opened_low                        int64
# year_opened_high                       int64
# year_closed_low                       object
# year_closed_high                      object
# data_primary_provenance               object
# area_deprivation_index                 int64
# area_deprivation_index_crime           int64
# area_deprivation_index_education       int64
# area_deprivation_index_employment      int64
# area_deprivation_index_health          int64
# area_deprivation_index_housing         int64
# area_deprivation_index_income          int64
# area_deprivation_index_services        int64
# area_geodemographic_supergroup        object
# area_geodemographic_group             object
# area_geodemographic_subgroup          object
# dtype: object

# %%
Map.shape
# Out:
# (4141, 41)

# %%
Map.head()
# Out:
#         museum_id                        museum_name  \
# 0        mm.New.1                    Titanic Belfast
# 1     mm.aim.1230       The Woodland Heritage Museum
# 2  mm.domus.WM019  Warwickshire Museum Of Rural Life
# 3     mm.aim.0485                     Jet Age Museum
# 4     mm.aim.0486             Jewish Military Museum
#
#                    address_line_1                 address_line_2  \
# 0                   1 Olympic Way                            NaN
# 1                             NaN                    Brokerswood
# 2  Warwick College of Agriculture  Horticulture & Equine Studies
# 3                  57 Crown Drive                 Bishops Cleeve
# 4               c/o Jewish Museum           Raymond Burton House
#
#               city  postcode   latitude  longitude  \
# 0          Belfast   BT3 9EP  54.608080  -5.909915
# 1      nr Westbury  BA13 4EH  51.270903  -2.231863
# 2  Moreton Morrell  CV35 9BL  52.197146  -1.555528
# 3       Cheltenham  GL52 8TA  51.940092  -2.060766
# 4           London   NW1 7NB  51.537163  -0.144517
#
#                                      admin_area_full      admin_area_1  \
# 0     Northern Ireland/Belfast (NI Loc Gov District)  Northern Ireland
# 1  England/South West (English Region)/Wiltshire ...           England
# 2  England/West Midlands (English Region)/Warwick...           England
# 3  England/South West (English Region)/Gloucester...           England
# 4  England/London (English Region)/Camden (London...           England
#
#     admin_area_2    admin_area_2_type     admin_area_3 admin_area_3_type  \
# 0        Belfast  NI Loc Gov District              NaN               NaN
# 1     South West       English Region        Wiltshire        English UA
# 2  West Midlands       English Region     Warwickshire    English County
# 3     South West       English Region  Gloucestershire    English County
# 4         London       English Region           Camden    London Borough
#
#         admin_area_4            admin_area_4_type accreditation  \
# 0                NaN                          NaN  Unaccredited
# 1                NaN                          NaN  Unaccredited
# 2  Stratford-on-Avon  English District or Borough  Unaccredited
# 3         Tewkesbury  English District or Borough    Accredited
# 4                NaN                          NaN  Unaccredited
#
#   governance_type governance_subtype    size              size_provenance  \
# 0     Independent     Not for profit   large                          NaN
# 1     Independent            Unknown   small         aim_size_designation
# 2      Government    Local Authority  medium  mm_prediction_random_forest
# 3     Independent     Not for profit  medium         aim_size_designation
# 4     Independent     Not for profit   small         aim_size_designation
#
#                  subject_matter_full     subject_matter  \
# 0  Sea and seafaring/Boats and ships  Sea and seafaring
# 1                Natural world/Other      Natural world
# 2             Rural Industry/Farming     Rural Industry
# 3          War and conflict/Airforce   War and conflict
# 4          War and conflict/Military   War and conflict
#
#   subject_matter_subtype_1 subject_matter_subtype_2  year_opened_low  \
# 0          Boats and ships                      NaN             2012
# 1                    Other                      NaN             1971
# 2                  Farming                      NaN             1984
# 3                 Airforce                      NaN             2013
# 4                 Military                      NaN             1996
#
#    year_opened_high year_closed_low year_closed_high data_primary_provenance  \
# 0              2012              na               na                     new
# 1              1971            2007             2017                     aim
# 2              1984              na               na                   domus
# 3              2013              na               na                     aim
# 4              1996            2015             2015                     aim
#
#    area_deprivation_index  area_deprivation_index_crime  \
# 0                       2                             3
# 1                       9                             8
# 2                       8                             9
# 3                       8                            10
# 4                       2                             1
#
#    area_deprivation_index_education  area_deprivation_index_employment  \
# 0                                 1                                  2
# 1                                 9                                  8
# 2                                 8                                 10
# 3                                 7                                  7
# 4                                 6                                  3
#
#    area_deprivation_index_health  area_deprivation_index_housing  \
# 0                              1                               4
# 1                              8                               6
# 2                              8                               5
# 3                              8                               7
# 4                              2                               1
#
#    area_deprivation_index_income  area_deprivation_index_services  \
# 0                              5                                5
# 1                              8                                4
# 2                              8                                1
# 3                              8                                4
# 4                              3                                4
#
#             area_geodemographic_supergroup      area_geodemographic_group  \
# 0  Business Education and Heritage Centres        Larger Towns and Cities
# 1                  Town and Country Living                 Country Living
# 2                       Countryside Living  English and Welsh Countryside
# 3                  Town and Country Living                 Country Living
# 4                      London Cosmopolitan            London Cosmopolitan
#
#   area_geodemographic_subgroup
# 0      Larger Towns and Cities
# 1               Country Living
# 2    Older Farming Communities
# 3               Country Living
# 4          London Cosmopolitan

# %%
Map.describe().T
# Out:
#                                     count         mean        std  \
# latitude                           4141.0    52.940834   1.947061
# longitude                          4141.0    -1.941854   1.840939
# year_opened_low                    4141.0  1968.629075  39.260207
# year_opened_high                   4141.0  1973.044192  40.254915
# area_deprivation_index             4141.0     5.440473   2.475902
# area_deprivation_index_crime       4141.0     5.430814   3.071744
# area_deprivation_index_education   4141.0     6.044675   2.607159
# area_deprivation_index_employment  4141.0     6.076310   2.761620
# area_deprivation_index_health      4141.0     6.017387   2.818964
# area_deprivation_index_housing     4141.0     3.966916   2.750954
# area_deprivation_index_income      4141.0     5.992755   2.624567
# area_deprivation_index_services    4141.0     4.775900   3.008283
#
#                                            min          25%          50%  \
# latitude                             49.914625    51.484802    52.475988
# longitude                            -8.091797    -3.087918    -1.844739
# year_opened_low                    1621.000000  1959.000000  1978.000000
# year_opened_high                   1621.000000  1961.000000  1982.000000
# area_deprivation_index                1.000000     4.000000     5.000000
# area_deprivation_index_crime          1.000000     3.000000     6.000000
# area_deprivation_index_education      1.000000     4.000000     6.000000
# area_deprivation_index_employment     1.000000     4.000000     6.000000
# area_deprivation_index_health         1.000000     4.000000     6.000000
# area_deprivation_index_housing        1.000000     1.000000     3.000000
# area_deprivation_index_income         1.000000     4.000000     6.000000
# area_deprivation_index_services       1.000000     2.000000     4.000000
#
#                                            75%          max
# latitude                             53.958016    60.790187
# longitude                            -0.463295     1.757594
# year_opened_low                    1993.000000  2021.000000
# year_opened_high                   1998.000000  2021.000000
# area_deprivation_index                7.000000    10.000000
# area_deprivation_index_crime          8.000000    10.000000
# area_deprivation_index_education      8.000000    10.000000
# area_deprivation_index_employment     8.000000    10.000000
# area_deprivation_index_health         8.000000    10.000000
# area_deprivation_index_housing        6.000000    10.000000
# area_deprivation_index_income         8.000000    10.000000
# area_deprivation_index_services       7.000000    10.000000

# %%
Map.drop(['museum_id','admin_area_1','admin_area_2','admin_area_2_type','admin_area_3','admin_area_3_type','admin_area_4','admin_area_4_type','subject_matter','subject_matter_subtype_1','subject_matter_subtype_2','size_provenance','data_primary_provenance'], axis=1, inplace=True)

# %%
Map.shape
# Out:
# (4141, 28)

# %%
Map.head()
# Out:
#                          museum_name                  address_line_1  \
# 0                    Titanic Belfast                   1 Olympic Way
# 1       The Woodland Heritage Museum                             NaN
# 2  Warwickshire Museum Of Rural Life  Warwick College of Agriculture
# 3                     Jet Age Museum                  57 Crown Drive
# 4             Jewish Military Museum               c/o Jewish Museum
#
#                   address_line_2             city  postcode   latitude  \
# 0                            NaN          Belfast   BT3 9EP  54.608080
# 1                    Brokerswood      nr Westbury  BA13 4EH  51.270903
# 2  Horticulture & Equine Studies  Moreton Morrell  CV35 9BL  52.197146
# 3                 Bishops Cleeve       Cheltenham  GL52 8TA  51.940092
# 4           Raymond Burton House           London   NW1 7NB  51.537163
#
#    longitude                                    admin_area_full accreditation  \
# 0  -5.909915     Northern Ireland/Belfast (NI Loc Gov District)  Unaccredited
# 1  -2.231863  England/South West (English Region)/Wiltshire ...  Unaccredited
# 2  -1.555528  England/West Midlands (English Region)/Warwick...  Unaccredited
# 3  -2.060766  England/South West (English Region)/Gloucester...    Accredited
# 4  -0.144517  England/London (English Region)/Camden (London...  Unaccredited
#
#   governance_type governance_subtype    size  \
# 0     Independent     Not for profit   large
# 1     Independent            Unknown   small
# 2      Government    Local Authority  medium
# 3     Independent     Not for profit  medium
# 4     Independent     Not for profit   small
#
#                  subject_matter_full  year_opened_low  year_opened_high  \
# 0  Sea and seafaring/Boats and ships             2012              2012
# 1                Natural world/Other             1971              1971
# 2             Rural Industry/Farming             1984              1984
# 3          War and conflict/Airforce             2013              2013
# 4          War and conflict/Military             1996              1996
#
#   year_closed_low year_closed_high  area_deprivation_index  \
# 0              na               na                       2
# 1            2007             2017                       9
# 2              na               na                       8
# 3              na               na                       8
# 4            2015             2015                       2
#
#    area_deprivation_index_crime  area_deprivation_index_education  \
# 0                             3                                 1
# 1                             8                                 9
# 2                             9                                 8
# 3                            10                                 7
# 4                             1                                 6
#
#    area_deprivation_index_employment  area_deprivation_index_health  \
# 0                                  2                              1
# 1                                  8                              8
# 2                                 10                              8
# 3                                  7                              8
# 4                                  3                              2
#
#    area_deprivation_index_housing  area_deprivation_index_income  \
# 0                               4                              5
# 1                               6                              8
# 2                               5                              8
# 3                               7                              8
# 4                               1                              3
#
#    area_deprivation_index_services           area_geodemographic_supergroup  \
# 0                                5  Business Education and Heritage Centres
# 1                                4                  Town and Country Living
# 2                                1                       Countryside Living
# 3                                4                  Town and Country Living
# 4                                4                      London Cosmopolitan
#
#        area_geodemographic_group area_geodemographic_subgroup
# 0        Larger Towns and Cities      Larger Towns and Cities
# 1                 Country Living               Country Living
# 2  English and Welsh Countryside    Older Farming Communities
# 3                 Country Living               Country Living
# 4            London Cosmopolitan          London Cosmopolitan

# %%
# using lambda function to eliminate the null values and add both addresses

Map['address_line_full'] = Map.apply(lambda x: '' if pd.isnull(x['address_line_1']) else x['address_line_1'], axis=1) +' '+ Map.apply(lambda x: '' if pd.isnull(x['address_line_2']) else x['address_line_2'], axis=1)


# drop both addresses
Map.drop(['address_line_1','address_line_2'], axis=1, inplace=True)


# moving the combined address from the end of the features to the positions of the dropped address
# insert column with insert(location, column_name, column_value)

column_to_move = Map.pop("address_line_full") # copies the values of the column
Map.insert(1, "address_line_full", column_to_move)

# %%
Map.head()
# Out:
#                          museum_name  \
# 0                    Titanic Belfast
# 1       The Woodland Heritage Museum
# 2  Warwickshire Museum Of Rural Life
# 3                     Jet Age Museum
# 4             Jewish Military Museum
#
#                                    address_line_full             city  \
# 0                                     1 Olympic Way           Belfast
# 1                                        Brokerswood      nr Westbury
# 2  Warwick College of Agriculture Horticulture & ...  Moreton Morrell
# 3                      57 Crown Drive Bishops Cleeve       Cheltenham
# 4             c/o Jewish Museum Raymond Burton House           London
#
#    postcode   latitude  longitude  \
# 0   BT3 9EP  54.608080  -5.909915
# 1  BA13 4EH  51.270903  -2.231863
# 2  CV35 9BL  52.197146  -1.555528
# 3  GL52 8TA  51.940092  -2.060766
# 4   NW1 7NB  51.537163  -0.144517
#
#                                      admin_area_full accreditation  \
# 0     Northern Ireland/Belfast (NI Loc Gov District)  Unaccredited
# 1  England/South West (English Region)/Wiltshire ...  Unaccredited
# 2  England/West Midlands (English Region)/Warwick...  Unaccredited
# 3  England/South West (English Region)/Gloucester...    Accredited
# 4  England/London (English Region)/Camden (London...  Unaccredited
#
#   governance_type governance_subtype    size  \
# 0     Independent     Not for profit   large
# 1     Independent            Unknown   small
# 2      Government    Local Authority  medium
# 3     Independent     Not for profit  medium
# 4     Independent     Not for profit   small
#
#                  subject_matter_full  year_opened_low  year_opened_high  \
# 0  Sea and seafaring/Boats and ships             2012              2012
# 1                Natural world/Other             1971              1971
# 2             Rural Industry/Farming             1984              1984
# 3          War and conflict/Airforce             2013              2013
# 4          War and conflict/Military             1996              1996
#
#   year_closed_low year_closed_high  area_deprivation_index  \
# 0              na               na                       2
# 1            2007             2017                       9
# 2              na               na                       8
# 3              na               na                       8
# 4            2015             2015                       2
#
#    area_deprivation_index_crime  area_deprivation_index_education  \
# 0                             3                                 1
# 1                             8                                 9
# 2                             9                                 8
# 3                            10                                 7
# 4                             1                                 6
#
#    area_deprivation_index_employment  area_deprivation_index_health  \
# 0                                  2                              1
# 1                                  8                              8
# 2                                 10                              8
# 3                                  7                              8
# 4                                  3                              2
#
#    area_deprivation_index_housing  area_deprivation_index_income  \
# 0                               4                              5
# 1                               6                              8
# 2                               5                              8
# 3                               7                              8
# 4                               1                              3
#
#    area_deprivation_index_services           area_geodemographic_supergroup  \
# 0                                5  Business Education and Heritage Centres
# 1                                4                  Town and Country Living
# 2                                1                       Countryside Living
# 3                                4                  Town and Country Living
# 4                                4                      London Cosmopolitan
#
#        area_geodemographic_group area_geodemographic_subgroup
# 0        Larger Towns and Cities      Larger Towns and Cities
# 1                 Country Living               Country Living
# 2  English and Welsh Countryside    Older Farming Communities
# 3                 Country Living               Country Living
# 4            London Cosmopolitan          London Cosmopolitan

# %%
# Columns with null values
Map.columns[Map.isnull().any()]
# Out:
# Index(['city', 'governance_subtype'], dtype='object')

# %%
# Total number of null values in dataset
Map.isnull().sum().sum()
# Out:
# 223

# %%
# Null values in this column
Map['city'].isnull().sum().sum()
# Out:
# 4

# %%
# Null values in this column
Map['governance_subtype'].isnull().sum().sum()
# Out:
# 219

# %%
# see sample null values of the column 'city'
Map[Map['city'].apply(lambda x: pd.isnull(x))]
# Out:
#                                             museum_name  \
# 525      Aycliffe And District Bus Preservation Society
# 963                             Bluebell Railway Museum
# 1233                                        Body Worlds
# 3694  Northern Irelands Secret Bunker - Cold War Museum
#
#                         address_line_full city  postcode   latitude  \
# 525                                        NaN   DL5 4UL  54.630414
# 963               Sheffield Park Station   NaN  TN22 3QL  50.995697
# 1233  London Pavilion 1 Piccadilly Circus  NaN   W1J 0DA  51.510397
# 3694                                       NaN  BT62 1QU  54.450961
#
#       longitude                                    admin_area_full  \
# 525   -1.565384  England/North East (English Region)/North East...
# 963   -0.001111  England/South East (English Region)/East Susse...
# 1233  -0.134592  England/London (English Region)/Westminster (L...
# 3694  -6.512593  Northern Ireland/Armagh City (NI Loc Gov Distr...
#
#      accreditation governance_type governance_subtype     size  \
# 525     Accredited     Independent     Not for profit    small
# 963     Accredited     Independent     Not for profit   medium
# 1233  Unaccredited     Independent            Private  unknown
# 3694  Unaccredited     Independent            Private    small
#
#                 subject_matter_full  year_opened_low  year_opened_high  \
# 525       Transport/Buses and trams             1980              1980
# 963   Transport/Trains and railways             2011              2011
# 1233      Medicine and health/Other             2018              2018
# 3694        War and conflict/Bunker             2010              2010
#
#      year_closed_low year_closed_high  area_deprivation_index  \
# 525               na               na                       5
# 963               na               na                       7
# 1233              na               na                       4
# 3694              na               na                       6
#
#       area_deprivation_index_crime  area_deprivation_index_education  \
# 525                              7                                 5
# 963                              7                                 8
# 1233                             3                                 5
# 3694                             9                                 7
#
#       area_deprivation_index_employment  area_deprivation_index_health  \
# 525                                   4                              2
# 963                                   9                             10
# 1233                                  7                              8
# 3694                                  8                              9
#
#       area_deprivation_index_housing  area_deprivation_index_income  \
# 525                               10                              4
# 963                                3                              9
# 1233                               1                              7
# 3694                              10                              4
#
#       area_deprivation_index_services  area_geodemographic_supergroup  \
# 525                                 6  Services and Industrial Legacy
# 963                                 1              Countryside Living
# 1233                                2             London Cosmopolitan
# 3694                                2         Town and Country Living
#
#                      area_geodemographic_group  area_geodemographic_subgroup
# 525   Services Manufacturing and Mining Legacy                 Mining Legacy
# 963                     Remoter Coastal Living         Ageing Coastal Living
# 1233                       London Cosmopolitan           London Cosmopolitan
# 3694              Northern Ireland Countryside  Northern Ireland Countryside

# %%
# since the total number of null is not much lets drop the rows with them using:
# df.dropna(subset=['column_name'], inplace=True)

Map.dropna(subset=['city','governance_subtype'], inplace=True)

# %%
# Columns with null values (we do not have any more null values)
Map.columns[Map.isnull().any()]
# Out:
# Index([], dtype='object')

# %%
# check shape

Map.shape
# Out:
# (3918, 27)

# %%
Map.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 3918 entries, 0 to 4140
# Data columns (total 27 columns):
#  #   Column                             Non-Null Count  Dtype
# ---  ------                             --------------  -----
#  0   museum_name                        3918 non-null   object
#  1   address_line_full                  3918 non-null   object
#  2   city                               3918 non-null   object
#  3   postcode                           3918 non-null   object
#  4   latitude                           3918 non-null   float64
#  5   longitude                          3918 non-null   float64
#  6   admin_area_full                    3918 non-null   object
#  7   accreditation                      3918 non-null   object
#  8   governance_type                    3918 non-null   object
#  9   governance_subtype                 3918 non-null   object
#  10  size                               3918 non-null   object
#  11  subject_matter_full                3918 non-null   object
#  12  year_opened_low                    3918 non-null   int64
#  13  year_opened_high                   3918 non-null   int64
#  14  year_closed_low                    3918 non-null   object
#  15  year_closed_high                   3918 non-null   object
#  16  area_deprivation_index             3918 non-null   int64
#  17  area_deprivation_index_crime       3918 non-null   int64
#  18  area_deprivation_index_education   3918 non-null   int64
#  19  area_deprivation_index_employment  3918 non-null   int64
#  20  area_deprivation_index_health      3918 non-null   int64
#  21  area_deprivation_index_housing     3918 non-null   int64
#  22  area_deprivation_index_income      3918 non-null   int64
#  23  area_deprivation_index_services    3918 non-null   int64
#  24  area_geodemographic_supergroup     3918 non-null   object
#  25  area_geodemographic_group          3918 non-null   object
#  26  area_geodemographic_subgroup       3918 non-null   object
# dtypes: float64(2), int64(10), object(15)
# memory usage: 857.1+ KB

# %%
# Let's see how the outliers look like

# %%
sns.boxplot(Map.latitude)
# Out:
# <Axes: ylabel='latitude'>

# %%
sns.boxplot(Map.longitude)
# Out:
# <Axes: ylabel='longitude'>

# %%
sns.boxplot(Map.year_opened_low)
# Out:
# <Axes: ylabel='year_opened_low'>

# %%
sns.boxplot(Map.year_opened_high)
# Out:
# <Axes: ylabel='year_opened_high'>

# %% [markdown]
# Do more numeric data boxplots to see the outliers

# %%
# group the museums to gain more insights

groupy = Map.groupby('size').size().sort_values(ascending=False)[:60]
groupy
# Out:
# size
# small      2261
# medium      963
# large       523
# unknown     159
# huge         12
# dtype: int64

# %%
groupy = Map.groupby('city').size().sort_values(ascending=False)[:60]
groupy
# Out:
# city
# London                 238
# York                    37
# Edinburgh               32
# Glasgow                 30
# Bristol                 27
# Manchester              25
# Liverpool               24
# Birmingham              24
# Bath                    23
# Norwich                 20
# Belfast                 19
# Nottingham              19
# Leicester               17
# Lincoln                 17
# Leeds                   16
# Winchester              15
# Sheffield               15
# Brighton                15
# Derby                   14
# Great Yarmouth          14
# Newport                 13
# Portsmouth              13
# Stoke-on-Trent          12
# Southampton             12
# Colchester              12
# Eastbourne              12
# Peterborough            11
# Preston                 11
# Salisbury               11
# Woodbridge              11
# Worcester               11
# Newark                  10
# Cheltenham              10
# Berwick-upon-Tweed      10
# Aberdeen                10
# Dorchester              10
# Chester                 10
# Guildford               10
# Stratford-upon-Avon     10
# Northampton             10
# Swindon                 10
# Wakefield                9
# Bradford                 9
# Coventry                 9
# Telford                  9
# Hereford                 9
# Middlesbrough            9
# Penzance                 9
# Swansea                  9
# Whitby                   9
# Kings Lynn               9
# Hull                     9
# Dundee                   9
# Spalding                 8
# Newcastle upon Tyne      8
# Huddersfield             8
# Chippenham               8
# Dumfries                 8
# Hastings                 8
# Barnsley                 8
# dtype: int64

# %%
groupy = Map.groupby('subject_matter_full').size().sort_values(ascending=False)[:60]
groupy
# Out:
# subject_matter_full
# Local Histories                                  857
# Buildings/Houses/Large houses                    409
# Arts/Fine and decorative arts                    161
# Transport/Trains and railways                    133
# War and conflict/Regiment                        129
# Mixed/Encyclopaedic                              110
# Mixed/Other                                       78
# Personality/Literary                              77
# Buildings/Houses/Medium houses                    72
# War and conflict/Airforce                         69
# Transport/Cars and motorbikes                     69
# Other                                             68
# War and conflict/Castles and forts                64
# Rural Industry/Farming                            58
# Leisure and sport/Toys and models                 55
# Sea and seafaring/Boats and ships                 48
# Industry and manufacture/Mining and quarrying     48
# Sea and seafaring/Mixed                           44
# War and conflict/Military                         42
# Archaeology/Roman                                 39
# Belief and identity/Religious buildings           38
# Personality/Other                                 37
# Buildings/Other                                   35
# Industry and manufacture/Other                    34
# Transport/Mixed                                   33
# War and conflict/Event or site                    33
# Industry and manufacture/Textiles                 32
# Utilities/Water and waste                         30
# Rural Industry/Rural life                         30
# Rural Industry/Watermills                         30
# Belief and identity/Religion                      29
# Buildings/Houses/Small houses                     29
# Transport/Aviation                                28
# Archaeology/Prehistory                            25
# Food and drink                                    24
# Leisure and sport/Rugby and football              22
# Leisure and sport/Other                           22
# Personality/Art                                   21
# Arts/Costume and textiles                         21
# Services/Police                                   21
# Personality/Political                             20
# Natural world/Mixed                               19
# Belief and identity/Ethnic group                  19
# Arts/Music                                        19
# Rural Industry/Windmills                          19
# Arts/Ceramics                                     18
# Arts/Other                                        18
# War and conflict/Other                            17
# Leisure and sport/Film Cinema and TV              16
# Medicine and health/Hospital                      16
# Personality/Religious                             16
# Transport/Buses and trams                         16
# Transport/Canals                                  15
# Mixed/Bygones                                     15
# War and conflict/Navy                             15
# Buildings/Penal                                   14
# Science and technology/Other                      14
# Industry and manufacture/Metals                   14
# Industry and manufacture/Mixed                    14
# Services/Fire                                     14
# dtype: int64

# %% [markdown]
# Do more goupings by the feature names to gain more insight

# %%
# see how 'area_geodemographic_supergroup' plot looks like in terms of count and their names and how many they are
import matplotlib.pyplot as plt
plt.figure(figsize=[10,4])
Map['area_geodemographic_supergroup'].value_counts().plot(kind='bar')
# Out:
# <Axes: >

# %%
#sns.countplot(Map, x="city", hue="size")

# see an approximate count of each feature

import matplotlib.pyplot as plt
import seaborn as sns


fig, ax = plt.subplots()
sns.countplot(Map, x="city", hue="size")
#sns.histplot(Map, ax=ax)  # distplot is deprecate and replaced by histplot
ax.set_xlim(0,15)
ax.set_xticks(range(1,20))
ax.tick_params(axis='x', rotation=90)
plt.show()

# %%
#See numberical data count

# see an approximate count of each feature

import matplotlib.pyplot as plt
import seaborn as sns


fig, ax = plt.subplots()
sns.histplot(Map, ax=ax)  # distplot is deprecate and replaced by histplot
ax.set_xlim(0,15)
ax.set_xticks(range(1,30))
plt.show()
# Out:
# /usr/local/lib/python3.10/dist-packages/IPython/core/pylabtools.py:151: UserWarning: Creating legend with loc="best" can be slow with large amounts of data.
#   fig.canvas.print_figure(bytes_io, **kw)
